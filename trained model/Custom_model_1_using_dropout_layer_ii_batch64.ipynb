# %% [markdown]
# config
# Runtime ->Change runtime type ->select GPU

# %% [markdown]
# #Mount Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Unzip data

# %%
from zipfile import ZipFile
file_path = "/content/drive/My Drive/Colab Notebooks/Thesis/image_data.zip"
with ZipFile(file_path,'r') as zip:
    zip.extractall()
    print("Done")
# Out:
# Done

# %% [markdown]
# #Count data

# %%
import os
total_training_samples = 0
for expression in os.listdir("/content/image_data/train"):    
    num = len(os.listdir("/content/image_data/train/"+expression))
    total_training_samples += num
    print(expression +" "+str(num)+" "+"images ")

print("Total training samples : ",total_training_samples)
# Out:
# neutral 1440 images
# sadness 1440 images
# disgust 1440 images
# surprise 1440 images
# fear 1440 images
# anger 1440 images
# happiness 1440 images
# Total training samples :  10080

# %%
total_validation_samples = 0
for expression in os.listdir("/content/image_data/validation"):
    num = len(os.listdir("/content/image_data/validation/"+expression))
    total_validation_samples += num
    print(expression +" "+str(num)+" "+"images ")

print("Total validation samples : ",total_validation_samples)
# Out:
# neutral 360 images
# sadness 360 images
# disgust 360 images
# surprise 360 images
# fear 360 images
# anger 360 images
# happiness 360 images
# Total validation samples :  2520

# %% [markdown]
# #Data Augmentation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
image_size = 48
batch_size = 64

datagen_train = ImageDataGenerator(rescale=1./255, 
                                   zoom_range=0.1, 
                                   rotation_range=10, 
                                   shear_range = 0.1, 
                                   horizontal_flip=True, 
                                   fill_mode="nearest")

train_generator = datagen_train.flow_from_directory("/content/image_data/train/",
                                                    target_size=(image_size,image_size),
                                                    color_mode="grayscale",
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    shuffle=True)

datagen_validation = ImageDataGenerator(rescale=1./255)

validation_generator = datagen_validation.flow_from_directory("/content/image_data/validation/",
                                                    target_size=(image_size,image_size),
                                                    color_mode="grayscale",
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    shuffle=True)
# Out:
# Found 10080 images belonging to 7 classes.
# Found 2520 images belonging to 7 classes.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout,Flatten, Conv2D
from tensorflow.keras.layers import BatchNormalization, MaxPooling2D
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

print("Tensorflow version:", tf.__version__)
# Out:
# Tensorflow version: 2.3.0

# %% [markdown]
# #Hyperparameter Tuning

# %%
epochs = 150
lr = 0.001
loss = "categorical_crossentropy"
optimizer = Adam(learning_rate = lr )

# %%
model = Sequential()

model.add(Conv2D(32 ,(3,3),activation='relu',input_shape = (48,48,1)))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(64,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(128,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())

model.add(Dropout(0.5))

model.add(Dense(256,activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(128,activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(7,activation='softmax'))

model.compile(optimizer =optimizer,loss = loss,metrics = ['accuracy'] )
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 46, 46, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 23, 23, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 21, 21, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               524544
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 903
# =================================================================
# Total params: 651,015
# Trainable params: 651,015
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
from IPython.display import Image

plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True)
Image('model.png',width=400, height=200)

# %%
print(train_generator.n)
print(validation_generator.n)
print(train_generator.batch_size)
steps_per_epoch = train_generator.n //train_generator.batch_size
validation_steps = validation_generator.n // validation_generator.batch_size

#early_stopping = EarlyStopping(patience=5)

history = model.fit( train_generator,
                    steps_per_epoch = total_training_samples//batch_size,
                    validation_data = validation_generator,
                    validation_steps = total_validation_samples//batch_size,
                    epochs = epochs)
#callbacks=[early_stopping]
# Out:
# 10080
# 2520
# 64
# Epoch 1/150
# 157/157 [==============================] - 7s 48ms/step - loss: 1.9033 - accuracy: 0.1782 - val_loss: 1.5869 - val_accuracy: 0.2949
# Epoch 2/150
# 157/157 [==============================] - 7s 46ms/step - loss: 1.7234 - accuracy: 0.2870 - val_loss: 1.4645 - val_accuracy: 0.3702
# Epoch 3/150
# 157/157 [==============================] - 7s 46ms/step - loss: 1.6224 - accuracy: 0.3336 - val_loss: 1.3782 - val_accuracy: 0.4215
# Epoch 4/150
# 157/157 [==============================] - 7s 45ms/step - loss: 1.5557 - accuracy: 0.3776 - val_loss: 1.3343 - val_accuracy: 0.4487
# Epoch 5/150
# 157/157 [==============================] - 7s 46ms/step - loss: 1.4958 - accuracy: 0.3996 - val_loss: 1.3361 - val_accuracy: 0.4563
# Epoch 6/150
# 157/157 [==============================] - 7s 46ms/step - loss: 1.4434 - accuracy: 0.4269 - val_loss: 1.2004 - val_accuracy: 0.4976
# Epoch 7/150
# 157/157 [==============================] - 7s 46ms/step - loss: 1.3871 - accuracy: 0.4579 - val_loss: 1.1830 - val_accuracy: 0.5421
# Epoch 8/150
# 157/157 [==============================] - 7s 46ms/step - loss: 1.3381 - accuracy: 0.4730 - val_loss: 1.1780 - val_accuracy: 0.5048
# Epoch 9/150
# 157/157 [==============================] - 7s 47ms/step - loss: 1.2918 - accuracy: 0.4991 - val_loss: 1.0983 - val_accuracy: 0.5677
# Epoch 10/150
# 157/157 [==============================] - 7s 47ms/step - loss: 1.2653 - accuracy: 0.5068 - val_loss: 1.1444 - val_accuracy: 0.5437
# Epoch 11/150
# 157/157 [==============================] - 7s 46ms/step - loss: 1.2357 - accuracy: 0.5206 - val_loss: 1.0855 - val_accuracy: 0.5497
# Epoch 12/150
# 157/157 [==============================] - 7s 46ms/step - loss: 1.2132 - accuracy: 0.5302 - val_loss: 1.0572 - val_accuracy: 0.5701
# Epoch 13/150
# 157/157 [==============================] - 7s 46ms/step - loss: 1.1812 - accuracy: 0.5490 - val_loss: 1.0654 - val_accuracy: 0.5701
# Epoch 14/150
# 157/157 [==============================] - 7s 46ms/step - loss: 1.1563 - accuracy: 0.5582 - val_loss: 0.9961 - val_accuracy: 0.5990
# Epoch 15/150
# 157/157 [==============================] - 7s 46ms/step - loss: 1.1360 - accuracy: 0.5697 - val_loss: 0.9891 - val_accuracy: 0.6226
# Epoch 16/150
# 157/157 [==============================] - 7s 46ms/step - loss: 1.1277 - accuracy: 0.5723 - val_loss: 0.9276 - val_accuracy: 0.6238
# Epoch 17/150
# 157/157 [==============================] - 7s 46ms/step - loss: 1.0991 - accuracy: 0.5827 - val_loss: 0.9413 - val_accuracy: 0.6234
# Epoch 18/150
# 157/157 [==============================] - 7s 46ms/step - loss: 1.0856 - accuracy: 0.5926 - val_loss: 0.8936 - val_accuracy: 0.6478
150
# 157/157 [==============================] - 7s 44ms/step - loss: 0.7520 - accuracy: 0.7263 - val_loss: 0.7559 - val_accuracy: 0.7179
# Epoch 81/150
# 157/157 [==============================] - 7s 45ms/step - loss: 0.7458 - accuracy: 0.7300 - val_loss: 0.7692 - val_accuracy: 0.7091
# Epoch 82/150
# 157/157 [==============================] - 7s 44ms/step - loss: 0.7509 - accuracy: 0.7263 - val_loss: 0.7958 - val_accuracy: 0.7095
# Epoch 83/150
# 157/157 [==============================] - 7s 44ms/step - loss: 0.7437 - accuracy: 0.7268 - val_loss: 0.6998 - val_accuracy: 0.7376
# Epoch 84/150
# 157/157 [==============================] - 7s 44ms/step - loss: 0.7475 - accuracy: 0.7304 - val_loss: 0.7309 - val_accuracy: 0.7220
# Epoch 85/150
# 157/157 [==============================] - 7s 44ms/step - loss: 0.7410 - accuracy: 0.7265 - val_loss: 0.7455 - val_accuracy: 0.7200
# Epoch 86/150
# 157/157 [==============================] - 7s 45ms/step - loss: 0.7415 - accuracy: 0.7330 - val_loss: 0.7300 - val_accuracy: 0.7288
# Epoch 87/150
# 157/157 [==============================] - 7s 45ms/step - loss: 0.7327 - accuracy: 0.7313 - val_loss: 0.7473 - val_accuracy: 0.7236
# Epoch 88/150
# 157/157 [==============================] - 7s 44ms/step - loss: 0.7400 - accuracy: 0.7299 - val_loss: 0.7304 - val_accuracy: 0.7268
# Epoch 89/150
# 157/157 [==============================] - 7s 44ms/step - loss: 0.7449 - accuracy: 0.7308 - val_loss: 0.7039 - val_accuracy: 0.7376
# Epoch 90/150
# 157/157 [==============================] - 7s 44ms/step - loss: 0.7238 - accuracy: 0.7404 - val_loss: 0.7054 - val_accuracy: 0.7360
# Epoch 91/150
# 157/157 [==============================] - 7s 44ms/step - loss: 0.7326 - accuracy: 0.7303 - val_loss: 0.6987 - val_accuracy: 0.7364
# Epoch 92/150
# 157/157 [==============================] - 7s 44ms/step - loss: 0.7449 - accuracy: 0.7306 - val_loss: 0.7008 - val_accuracy: 0.7396
# Epoch 93/150
# 157/157 [==============================] - 7s 45ms/step - loss: 0.7198 - accuracy: 0.7377 - val_loss: 0.7135 - val_accuracy: 0.7336
# Epoch 94/150
# 157/157 [==============================] - 7s 44ms/step - loss: 0.7221 - accuracy: 0.7355 - val_loss: 0.6963 - val_accuracy: 0.7416
# Epoch 95/150
# 157/157 [==============================] - 7s 44ms/step - loss: 0.7193 - accuracy: 0.7336 - val_loss: 0.6934 - val_accuracy: 0.7360
# Epoch 96/150
# 157/157 [==============================] - 7s 46ms/step - loss: 0.7249 - accuracy: 0.7364 - val_loss: 0.6837 - val_accuracy: 0.7444
# Epoch 97/150
# 157/157 [==============================] - 7s 45ms/step - loss: 0.7238 - accuracy: 0.7312 - val_loss: 0.7348 - val_accuracy: 0.7308
# Epoch 98/150
# 157/157 [==============================] - 7s 44ms/step - loss: 0.7079 - accuracy: 0.7410 - val_loss: 0.7813 - val_accuracy: 0.7095
# Epoch 99/150
# 157/157 [==============================] - 7s 44ms/step - loss: 0.7143 - accuracy: 0.7468 - val_loss: 0.7522 - val_accuracy: 0.7196
# Epoch 100/150
# 157/157 [==============================] - 7s 44ms/step - loss: 0.7136 - accuracy: 0.7400 - val_loss: 0.6926 - val_accuracy: 0.7428
# Epoch 101/150
# 157/157 [==============================] - 7s 44ms/step - loss: 0.7131 - accuracy: 0.7460 - val_loss: 0.6715 - val_accuracy: 0.7460
# Epoch 102/150
# 157/157 [==============================] - 7s 45ms/step - loss: 0.7113 - accuracy: 0.7331 - val_loss: 0.6904 - val_accuracy: 0.7304
# Epoch 103/150
# 157/157 [==============================] - 7s 44ms/step - loss: 0.7191 - accuracy: 0.7394 - val_loss: 0.7263 - val_accuracy: 0.7316
# Epoch 104/150
# 157/157 [==============================] - 7s 45ms/step - loss: 0.7191 - accuracy: 0.7336 - val_loss: 0.7285 - val_accuracy: 0.7276
# Epoch 105/150
# 157/157 [==============================] - 7s 45ms/step - loss: 0.7105 - accuracy: 0.7410 - val_loss: 0.7391 - val_accuracy: 0.7364
# Epoch 106/150
# 157/157 [==============================] - 7s 45ms/step - loss: 0.6998 - accuracy: 0.7419 - val_loss: 0.6941 - val_accuracy: 0.7424
# Epoch 107/150
# 157/157 [==============================] - 7s 44ms/step - loss: 0.6875 - accuracy: 0.7442 - val_loss: 0.7138 - val_accuracy: 0.7428
# Epoch 108/150
# 157/157 [==============================] - 7s 45ms/step - loss: 0.6782 - accuracy: 0.7485 - val_loss: 0.7499 - val_accuracy: 0.7256
# Epoch 109/150
# 157/157 [==============================] - 7s 45ms/step - loss: 0.6968 - accuracy: 0.7439 - val_loss: 0.7336 - val_accuracy: 0.7175
# Epoch 110/150
# 157/157 [==============================] - 7s 45ms/step - loss: 0.6959 - accuracy: 0.7463 - val_loss: 0.7185 - val_accuracy: 0.7260
# Epoch 111/150
# 157/157 [==============================] - 7s 44ms/step - loss: 0.6842 - accuracy: 0.7489 - val_loss: 0.7268 - val_accuracy: 0.7280
# Epoch 112/150
# 157/157 [==============================] - 7s 44ms/step - loss: 0.6917 - accuracy: 0.7442 - val_loss: 0.7524 - val_accuracy: 0.7216
# Epoch 113/150
# 157/157 [==============================] - 7s 45ms/step - loss: 0.6864 - accuracy: 0.7486 - val_loss: 0.7057 - val_accuracy: 0.7424
# Epoch 114/150
# 157/157 [==============================] - 7s 44ms/step - loss: 0.6915 - accuracy: 0.7461 - val_loss: 0.6955 - val_accuracy: 0.7448
# Epoch 115/150
# 157/157 [==============================] - 7s 45ms/step - loss: 0.6876 - accuracy: 0.7502 - val_loss: 0.7699 - val_accuracy: 0.7204
# Epoch 116/150
# 157/157 [==============================] - 7s 45ms/step - loss: 0.6809 - accuracy: 0.7582 - val_loss: 0.7286 - val_accuracy: 0.7332
# Epoch 117/150
# 157/157 [==============================] - 7s 44ms/step - loss: 0.6909 - accuracy: 0.7528 - val_loss: 0.7465 - val_accuracy: 0.7167
# Epoch 118/150
# 157/157 [==============================] - 7s 44ms/step - loss: 0.6861 - accuracy: 0.7506 - val_loss: 0.7166 - val_accuracy: 0.7304
# Epoch 119/150
# 157/157 [==============================] - 7s 44ms/step - loss: 0.6839 - accuracy: 0.7523 - val_loss: 0.7020 - val_accuracy: 0.7416
# Epoch 120/150
# 157/157 [==============================] - 7s 44ms/step - loss: 0.6852 - accuracy: 0.7508 - val_loss: 0.7334 - val_accuracy: 0.7276
# Epoch 121/150
# 157/157 [==============================] - 7s 45ms/step - loss: 0.6759 - accuracy: 0.7557 - val_loss: 0.6929 - val_accuracy: 0.7372
# Epoch 122/150
# 157/157 [==============================] - 7s 44ms/step - loss: 0.7021 - accuracy: 0.7471 - val_loss: 0.6990 - val_accuracy: 0.7420
# Epoch 123/150
# 157/157 [==============================] - 7s 44ms/step - loss: 0.6664 - accuracy: 0.7578 - val_loss: 0.7384 - val_accuracy: 0.7288
# Epoch 124/150
# 157/157 [==============================] - 7s 44ms/step - loss: 0.6595 - accuracy: 0.7586 - val_loss: 0.6857 - val_accuracy: 0.7456
# Epoch 125/150
# 157/157 [==============================] - 7s 44ms/step - loss: 0.6731 - accuracy: 0.7554 - val_loss: 0.7119 - val_accuracy: 0.7308
# Epoch 126/150
# 157/157 [==============================] - 7s 44ms/step - loss: 0.6657 - accuracy: 0.7562 - val_loss: 0.7045 - val_accuracy: 0.7348
# Epoch 127/150
# 157/157 [==============================] - 7s 45ms/step - loss: 0.6713 - accuracy: 0.7605 - val_loss: 0.7019 - val_accuracy: 0.7388
# Epoch 128/150
# 157/157 [==============================] - 7s 44ms/step - loss: 0.6661 - accuracy: 0.7559 - val_loss: 0.7331 - val_accuracy: 0.7248
# Epoch 129/150
# 157/157 [==============================] - 7s 44ms/step - loss: 0.6566 - accuracy: 0.7583 - val_loss: 0.7133 - val_accuracy: 0.7276
# Epoch 130/150
# 157/157 [==============================] - 7s 45ms/step - loss: 0.6737 - accuracy: 0.7527 - val_loss: 0.7369 - val_accuracy: 0.7200
# Epoch 131/150
# 157/157 [==============================] - 7s 44ms/step - loss: 0.6649 - accuracy: 0.7587 - val_loss: 0.6873 - val_accuracy: 0.7388
# Epoch 132/150
# 157/157 [==============================] - 7s 44ms/step - loss: 0.6574 - accuracy: 0.7560 - val_loss: 0.7536 - val_accuracy: 0.7111
# Epoch 133/150
# 157/157 [==============================] - 7s 44ms/step - loss: 0.6585 - accuracy: 0.7612 - val_loss: 0.6913 - val_accuracy: 0.7452
# Epoch 134/150
# 157/157 [==============================] - 7s 45ms/step - loss: 0.6610 - accuracy: 0.7589 - val_loss: 0.7284 - val_accuracy: 0.7248
# Epoch 135/150
# 157/157 [==============================] - 7s 44ms/step - loss: 0.6640 - accuracy: 0.7591 - val_loss: 0.6991 - val_accuracy: 0.7404
# Epoch 136/150
# 157/157 [==============================] - 7s 44ms/step - loss: 0.6636 - accuracy: 0.7633 - val_loss: 0.6733 - val_accuracy: 0.7516
# Epoch 137/150
# 157/157 [==============================] - 7s 44ms/step - loss: 0.6467 - accuracy: 0.7619 - val_loss: 0.6826 - val_accuracy: 0.7440
# Epoch 138/150
# 157/157 [==============================] - 7s 45ms/step - loss: 0.6561 - accuracy: 0.7578 - val_loss: 0.6869 - val_accuracy: 0.7452
# Epoch 139/150
# 157/157 [==============================] - 7s 44ms/step - loss: 0.6484 - accuracy: 0.7621 - val_loss: 0.7377 - val_accuracy: 0.7308
# Epoch 140/150
# 157/157 [==============================] - 7s 46ms/step - loss: 0.6689 - accuracy: 0.7515 - val_loss: 0.7015 - val_accuracy: 0.7424
# Epoch 141/150
# 157/157 [==============================] - 7s 45ms/step - loss: 0.6402 - accuracy: 0.7670 - val_loss: 0.6987 - val_accuracy: 0.7484
# Epoch 142/150
# 157/157 [==============================] - 7s 44ms/step - loss: 0.6451 - accuracy: 0.7629 - val_loss: 0.7036 - val_accuracy: 0.7356
# Epoch 143/150
# 157/157 [==============================] - 7s 45ms/step - loss: 0.6549 - accuracy: 0.7594 - val_loss: 0.6833 - val_accuracy: 0.7416
# Epoch 144/150
# 157/157 [==============================] - 7s 44ms/step - loss: 0.6427 - accuracy: 0.7647 - val_loss: 0.6893 - val_accuracy: 0.7524
# Epoch 145/150
# 157/157 [==============================] - 7s 44ms/step - loss: 0.6522 - accuracy: 0.7614 - val_loss: 0.6857 - val_accuracy: 0.7532
# Epoch 146/150
# 157/157 [==============================] - 7s 44ms/step - loss: 0.6540 - accuracy: 0.7650 - val_loss: 0.7066 - val_accuracy: 0.7308
# Epoch 147/150
# 157/157 [==============================] - 7s 44ms/step - loss: 0.6427 - accuracy: 0.7662 - val_loss: 0.7442 - val_accuracy: 0.7244
# Epoch 148/150
# 157/157 [==============================] - 7s 44ms/step - loss: 0.6390 - accuracy: 0.7681 - val_loss: 0.6881 - val_accuracy: 0.7456
# Epoch 149/150
# 157/157 [==============================] - 7s 44ms/step - loss: 0.6296 - accuracy: 0.7698 - val_loss: 0.6781 - val_accuracy: 0.7480
# Epoch 150/150
# 157/157 [==============================] - 7s 44ms/step - loss: 0.6362 - accuracy: 0.7715 - val_loss: 0.6852 - val_accuracy: 0.7448

# %%
print(history.history.keys())
#history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')
plt.savefig('acc_2.png', dpi=300, bbox_inches='tight')
plt.show()

#history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.savefig('loss_2.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# # Visualize training,validation history

# %% [markdown]
# #Save model weights [ h5 ]

# %%
model.save_weights("model_2.h5")
print("save model to disk")
# Out:
# save model to disk

# %% [markdown]
# #Save model architecture [ JSON ]

# %%
model_json = model.to_json()
with open("model_2.json","w") as json_file:
     json_file.write(model_json)
